# %%
#func= 4*x**3+9*x**2-4*x-20
import numpy as npy
#from numpy import linalg as la

itr = 0
exit = False
err_thrshld = 0.001 # need to change this value
learning_rate = 0.1 # need to change this value
max_itrs = 200 #should change
x10=1
x20=-3
print ("Starting while")
x1=x10
x2=x20
while not exit:
 #   itr=itr+1
   # print (itr)
  #  print(x1,x2)
    fx = 1.5*(x1**2)+(x2**2)-2*(x1*x2)+2*(x1**3)+0.5*(x1**4)
    dx1 = 3*x1 -2*x2+6*(x1**2)+2*(x1**3)
    dx2 = 2*x2 - 2*x1
    print (round(x1,6)," ", round(x2,6),"  ", round(dx1,6),"  ", round(dx2,6), " ",round(fx,6))
    dx = npy.array([dx1,dx2])
    if( npy.sqrt(dx1**2+dx2**2) < err_thrshld):
        exit = True
    if(itr>max_itrs):
        print("max itrs over")
        exit =True
    x1=x1-(learning_rate * dx1)
    x2=x2-(learning_rate * dx2)

print ("the minimum value is:",fx)
# Out:
# Starting while
# 1   -3    17    -8   19.0
# -0.7   -2.2    4.554    -3.0   1.92905
# -1.1554   -1.9    5.258694    -1.4892   -0.971852
# -1.681269   -1.75108    5.913576    -0.139621   -4.091548
# -2.272627   -1.737118    4.169875    1.071018   -7.268541
# -2.689615   -1.84422    0.110269    1.69079   -8.416211
# -2.700641   -2.013299    0.291395    1.374685   -8.677581
# -2.729781   -2.150767    0.139377    1.158027   -8.857984
# -2.743719   -2.26657    0.160553    0.954297   -8.982385
# -2.759774   -2.362    0.103971    0.795548   -9.06801
# -2.770171   -2.441555    0.099942    0.657233   -9.12686
# -2.780165   -2.507278    0.072407    0.545775   -9.167256
# -2.787406   -2.561855    0.065049    0.451101   -9.194957
# -2.793911   -2.606965    0.049638    0.373891   -9.213939
# -2.798875   -2.644354    0.043198    0.30904   -9.226936
# -2.803194   -2.675258    0.033892    0.255872   -9.235832
# -2.806584   -2.700846    0.028989    0.211476   -9.241918
# ...
